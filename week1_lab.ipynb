# %% [markdown]
# <a href="https://colab.research.google.com/github/afzalqodirov/week1_lab/blob/main/week1_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Afzal Qodirov"

# %%
my_enrollment_number = "A85205225008"

# %%
my_hobby = "Trying something new"

# %%
print(f"Hello, my name is {my_name}, and my my enrollment number is {my_enrollment_number}. I like {my_hobby}.")
# Out:
# Hello, my name is Afzal Qodirov, and my my enrollment number is A85205225008. I like Trying something new.
